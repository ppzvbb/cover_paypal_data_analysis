# %%
import requests
import pandas as pd

def fetch_paginated_api(url, token, params=None, page_param="page", limit_param="limit", 
                        limit=100, max_pages=None, as_dataframe=True):
    """
    Fetch paginated data from a Bearer-token protected API endpoint.

    Args:
        url (str): The API endpoint URL.
        token (str): Your Bearer token.
        params (dict, optional): Extra query parameters.
        page_param (str): The name of the 'page' parameter in the API (default: 'page').
        limit_param (str): The name of the 'limit' parameter in the API (default: 'limit').
        limit (int): Number of records per page (default: 100).
        max_pages (int, optional): Maximum number of pages to fetch (for safety).
        as_dataframe (bool): Return as pandas DataFrame if True, else return raw JSON.

    Returns:
        pd.DataFrame or list: Combined results from all pages.
    """
    headers = {"Authorization": f"Bearer {token}"}
    all_data = []
    page = 1

    while True:
        query_params = params.copy() if params else {}
        query_params.update({page_param: page, limit_param: limit})
        
        response = requests.get(url, headers=headers, params=query_params)
        
        if response.status_code != 200:
            raise Exception(f"Error {response.status_code}: {response.text}")

        data = response.json()

        # Handle list or dict response
        if isinstance(data, dict):
            # Look for list-like values inside the dict
            for v in data.values():
                if isinstance(v, list):
                    chunk = v
                    break
            else:
                chunk = [data]
        else:
            chunk = data

        if not chunk:  # stop if no data returned
            break

        all_data.extend(chunk)
        page += 1

        if max_pages and page > max_pages:
            break

    if as_dataframe:
        return pd.DataFrame(all_data)
    return all_data

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

API_TOKEN = os.getenv("API_TOKEN")
API_URL = os.getenv("API_URL")
endpoint_billing_plans = "billing/plans"
endpoint_billing_subscriptions = "billing/subscriptions"

# %%
url=f"{API_URL.rstrip('/')}/{endpoint_billing_plans.lstrip('/')}"
print(url)
# Out:
# https://api-m.sandbox.paypal.com/v1/billing/plans

# %%
df_billing_plans = fetch_paginated_api(
    url=f"{API_URL.rstrip('/')}/{endpoint_billing_plans.lstrip('/')}",
    token=API_TOKEN,
    limit=20,
    max_pages=20   # safety cap
)
print(df_billing_plans.shape)
# Out:
# (28, 8)

# %%
df_billing_plans
# Out:
#                             id              product_id  \
# 0   P-2FT022935G912211FM6NCCGA  PROD-14R35346HN469743F
# 1   P-84G57112F2188035DM6NCWQA  PROD-688529992L681534R
# 2   P-76S59504HH513745WM6NDM6A  PROD-0DP6039620958130N
# 3   P-17B61707G0673854KM6NUXHY  PROD-9A413705KL335452R
# 4   P-5JG56959P6399794RM6NZ6ZA  PROD-34Y162077A826044N
# 5   P-31560533R81481050M7L6T2A  PROD-2HJ69743CN927261X
# 6   P-92D38243N40194158M7NJPXY  PROD-6TR13458AT717121C
# 7   P-5VL190622N512041LM7NMTBY  PROD-3Y7929373F111070T
# 8   P-79G57279YY868574UM7NMXHI  PROD-3Y7929373F111070T
# 9   P-68G5901538848992RM7OP2VI  PROD-4K145476CP508805P
# 10  P-4EF84597WP026574UM7RHGLI  PROD-8X617405E3414601M
# 11  P-7S298361B88352332NAAMX4Q  PROD-2JC517433U467094M
# 12  P-2H96887045401520YNAAPWEY  PROD-6FG93409610726902
# 13  P-1KS07253RY769973WNAAPWFA  PROD-09X411976S9895614
# 14  P-8JD43870S2616570TNAOD6LA  PROD-1N233560KF951334Y
# 15  P-6NL02592RA233701BNAOD73A  PROD-0CH89483LT2827058
# 16  P-58K813737V2930621NAOLMJI  PROD-6A420780YM9443602
# 17  P-6PV22905JP8584921NAOLPUI  PROD-5AJ445677J543373J
# 18  P-9VV03775WB4333636NAOLQNI  PROD-2SY57876VF830724Y
# 19  P-18H18694EW153473SNAOLREY  PROD-54267302NG010882B
# 20  P-54189484D1747082LNAOLR4Q  PROD-96F039945Y920934H
# 21  P-9NG451911P998205NNAOMQWQ  PROD-75H48396LG612592C
# 22  P-3FY16427GR944450YNAOMROA  PROD-8A6227139P682721P
# 23  P-08A8913320465473NNAOMSIA  PROD-026608710B973084P
# 24  P-4RL12778SR467413MNAO4MUQ  PROD-1N233560KF951334Y
# 25  P-6AD30428NW379154ANAQ3GOA  PROD-0SV76834GA781903L
# 26  P-98U90491T8827345WNARP7GQ  PROD-9B1538178W809712M
# 27  P-8D239304495991037NARQBFQ  PROD-3SN97728LY114201K
#
#                                                  name  status  \
# 0                        Video Streaming Service Plan  ACTIVE
# 1                                          Lebenslauf  ACTIVE
# 2                                           Dolomiten  ACTIVE
# 3                                                 WUH  ACTIVE
# 4                               Donnerstag Nachmittag  ACTIVE
# 5                                    FISCH & FANG Abo  ACTIVE
# 6                                   WILD UND HUND Abo  ACTIVE
# 7                                    FISCH & FANG Abo  ACTIVE
# 8                                    FISCH & FANG Abo  ACTIVE
# 9                           WILD UND HUND Digital-Abo  ACTIVE
# 10                                  WILD UND HUND Abo  ACTIVE
# 11                                  WILD UND HUND Abo  ACTIVE
# 12       JAGEN WELTWEIT Abo für Schüler und Studenten  ACTIVE
# 13  DICK Filetiermesser 21 cm “Norwegen” + DER RAU...  ACTIVE
# 14                                   FISCH & FANG Abo  ACTIVE
# 15                                 JAGEN WELTWEIT Abo  ACTIVE
# 16                         JAGEN WELTWEIT Digital-Abo  ACTIVE
# 17       Mora Messer +  Mini-Abo DEUTSCHE JAGDZEITUNG  ACTIVE
# 18  Deutsche Jagdzeitung Abo für Schüler und Stude...  ACTIVE
# 19    DEUTSCHE JAGDZEITUNG Abo +  Farm-Land Wildwanne  ACTIVE
# 20                           FISCH & FANG Digital-Abo  ACTIVE
# 21                 WILD UND HUND Exklusiv Digital-Abo  ACTIVE
# 22                  Deutsche Jagdzeitung Geschenk-Abo  ACTIVE
# 23           LÖWE Jagdschere + Mini-Abo WILD UND HUND  ACTIVE
# 24                                   FISCH & FANG Abo  ACTIVE
# 25                               NORWEGEN-Magazin Abo  ACTIVE
# 26                          WILD UND HUND Digital-Abo  ACTIVE
# 27                                  WILD UND HUND Abo  ACTIVE
#
#                            description usage_type           create_time  \
# 0   Video Streaming Service basic plan   LICENSED  2025-01-29T12:37:44Z
# 1        Das weiss doch vorher niemand   LICENSED  2025-01-29T13:21:04Z
# 2        Das weiss doch vorher niemand   LICENSED  2025-01-29T14:08:56Z
# 3                            Jahresabo   LICENSED  2025-01-30T09:51:27Z
# 4        Das weiss doch vorher niemand   LICENSED  2025-01-30T15:48:52Z
# 5                                  NaN   LICENSED  2025-03-17T09:22:48Z
# 6                                  NaN   LICENSED  2025-03-19T10:09:35Z
# 7                                  NaN   LICENSED  2025-03-19T13:41:27Z
# 8                                  NaN   LICENSED  2025-03-19T13:50:21Z
# 9                                  NaN   LICENSED  2025-03-21T05:47:01Z
# 10                                 NaN   LICENSED  2025-03-25T09:11:09Z
# 11                                 NaN   LICENSED  2025-04-17T09:37:54Z
# 12                                 NaN   LICENSED  2025-04-17T12:58:59Z
# 13                                 NaN   LICENSED  2025-04-17T12:59:00Z
# 14                                 NaN   LICENSED  2025-05-08T05:20:44Z
# 15                                 NaN   LICENSED  2025-05-08T05:23:56Z
# 16                                 NaN   LICENSED  2025-05-08T13:48:21Z
# 17                                 NaN   LICENSED  2025-05-08T13:55:29Z
# 18                                 NaN   LICENSED  2025-05-08T13:57:09Z
# 19                                 NaN   LICENSED  2025-05-08T13:58:43Z
# 20                                 NaN   LICENSED  2025-05-08T14:00:18Z
# 21                                 NaN   LICENSED  2025-05-08T15:06:02Z
# 22                                 NaN   LICENSED  2025-05-08T15:07:36Z
# 23                                 NaN   LICENSED  2025-05-08T15:09:20Z
# 24                                 NaN   LICENSED  2025-05-09T09:09:38Z
# 25                                 NaN   LICENSED  2025-05-12T08:37:12Z
# 26                                 NaN   LICENSED  2025-05-13T08:15:22Z
# 27                                 NaN   LICENSED  2025-05-13T08:19:34Z
#
#                                                 links
# 0   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 1   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 2   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 3   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 4   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 5   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 6   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 7   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 8   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 9   [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 10  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 11  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 12  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 13  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 14  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 15  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 16  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 17  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 18  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 19  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 20  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 21  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 22  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 23  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 24  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 25  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 26  [{'href': 'https://api.sandbox.paypal.com/v1/b...
# 27  [{'href': 'https://api.sandbox.paypal.com/v1/b...

# %%
df_subscriptions_list = fetch_paginated_api(
    url=f"{API_URL.rstrip('/')}/{endpoint_billing_subscriptions.lstrip('/')}",
# 36  ACTIVE  I-KV2AM6EUBLCD         False  2025-05-13T08:15:47Z
# 37  ACTIVE  I-2BL1PR1T0R8R         False  2025-05-13T08:19:53Z
# 38  ACTIVE  I-BXKEMNCLDVVA         False  2025-05-13T14:08:42Z
#
#                                                 links
# 0   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 1   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 2   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 3   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 4   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 5   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 6   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 7   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 8   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 9   [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 10  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 11  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 12  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 13  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 14  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 15  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 16  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 17  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 18  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 19  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 20  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 21  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 22  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 23  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 24  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 25  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 26  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 27  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 28  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 29  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 30  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 31  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 32  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 33  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 34  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 35  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 36  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 37  [{'href': 'https://api-m.sandbox.paypal.com/v1...
# 38  [{'href': 'https://api-m.sandbox.paypal.com/v1...

# %%
import oracledb

# Connect using username/password
connection = oracledb.connect(
    user="your_username",
    password="your_password",
    dsn="host:port/service_name"  # e.g. "localhost:1521/XEPDB1"
)

cursor = connection.cursor()
cursor.execute("SELECT sysdate FROM dual")

for row in cursor:
    print(row)

cursor.close()
connection.close()

# %%
df_cover = pd.read_sql("SELECT * FROM employees WHERE ROWNUM <= 10", con=connection)
df_cover.head()
